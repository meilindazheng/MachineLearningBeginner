# %% [markdown]
# # Classification Task dengan Random Forest

# %% [markdown]
# ## General ML Model Training
# - Proses training machine learning selalu diawali dengan training set
# - Training set akan digunakan untuk mentraining model , model yang telah ditraining akan dinamakan trained model
# - Training set akan digunakan untuk melakukan prediksi sekumpulan feature baru

# %% [markdown]
# ## Ensemble Learning : heterogeneus dan homogeneus
# - Ensemble learning merupakan teknik untuk menggabungkan beberapa model untuk melakukan prediksi
# ![Screenshot%202022-05-26%20200026.png](attachment:Screenshot%202022-05-26%20200026.png)

# %% [markdown]
# ## Bagging : Bootstrap Aggregating
# ![Screenshot%202022-05-26%20200807-2.png](attachment:Screenshot%202022-05-26%20200807-2.png)

# %% [markdown]
# ## Random Forest
# ![Screenshot%202022-05-26%20201916.png](attachment:Screenshot%202022-05-26%20201916.png)
